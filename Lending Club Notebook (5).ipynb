# %%
import pandas as pd

df = pd.read_csv('/Users/Vlad/Desktop/Lending Club/lending-club/accepted_2007_to_2018Q4.csv')
# Out:
# /Users/Vlad/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (0,19,59,118,129,130,131,134,135,136,139,145,146,147) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
for column in df.columns:
    print(column)
# Out:
# id
# member_id
# loan_amnt
# funded_amnt
# funded_amnt_inv
# term
# int_rate
# installment
# grade
# sub_grade
# emp_title
# emp_length
# home_ownership
# annual_inc
# verification_status
# issue_d
# loan_status
# pymnt_plan
# url
# desc
# purpose
# title
# zip_code
# addr_state
# dti
# delinq_2yrs
# earliest_cr_line
# fico_range_low
# fico_range_high
# inq_last_6mths
# mths_since_last_delinq
# mths_since_last_record
# open_acc
# pub_rec
# revol_bal
# revol_util
# total_acc
# initial_list_status
# out_prncp
# out_prncp_inv
# total_pymnt
# total_pymnt_inv
# total_rec_prncp
# total_rec_int
# total_rec_late_fee
# recoveries
# collection_recovery_fee
# last_pymnt_d
# last_pymnt_amnt
# next_pymnt_d
# last_credit_pull_d
# last_fico_range_high
# last_fico_range_low
# collections_12_mths_ex_med
# mths_since_last_major_derog
# policy_code
# application_type
# annual_inc_joint
# dti_joint
# verification_status_joint
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal
# open_acc_6m
# open_act_il
# ...

# %%
df_sample = df.sample(n = 4000, replace = False) 
# df.drop_duplicates(keep=False,inplace=True)

# %%
df_sample.tail()
# Out:
#                id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 679237   78985195        NaN    15000.0      15000.0          15000.0
# 977661  102325436        NaN     4900.0       4900.0           4900.0
# 723371   77051320        NaN    35000.0      35000.0          35000.0
# 740145   76194145        NaN    24000.0      24000.0          24000.0
# 150763   59452266        NaN    29950.0      29950.0          29925.0
#
#               term  int_rate  installment grade sub_grade  ...  \
# 679237   36 months      5.32       451.73     A        A1  ...
# 977661   36 months      8.24       154.10     B        B1  ...
# 723371   60 months     21.18       950.42     E        E3  ...
# 740145   60 months     19.53       629.60     D        D5  ...
# 150763   60 months     21.99       827.02     F        F1  ...
#
#        hardship_payoff_balance_amount hardship_last_payment_amount  \
# 679237                            NaN                          NaN
# ...

# %%
df_sample.shape
# Out:
# (4000, 151)

# %%
df_sample.drop_duplicates(keep=False,inplace=True)

# %%
df_sample.shape
# Out:
# (4000, 151)

# %%
loan = df_sample[['id', 'loan_amnt', 'int_rate', 'term', 'purpose', 
                  'issue_d', 'loan_status', 'grade', 'home_ownership']].copy()
import random
mem_id = random.sample(range(0, 5000), 4000)
loan['member_id'] = mem_id
loan = loan[['id', 'loan_amnt', 'int_rate', 'term', 'purpose', 
                  'issue_d', 'loan_status', 'member_id', 'grade', 'home_ownership']]

# %%
borrower = df_sample[['title', 'annual_inc', 'addr_state', 'fico_range_low']].copy()

borrower['member_id'] = mem_id
borrower = borrower[['member_id', 'title', 'annual_inc', 'addr_state', 'fico_range_low']]

# %%
import numpy as np 
loan_status = df_sample[['loan_status']].copy()
loan_status_nodupl = loan_status.drop_duplicates(keep='last')
import numpy as np 
  
# numpy array 
loan_status_nodupl['index'] = np.array([0, 1, 2, 3, 4, 5]) 
loan_status_nodupl = loan_status_nodupl[['index', 'loan_status']]
# Out:
# /Users/Vlad/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
credit_rating = df_sample[['grade']].copy()
credit_rating_nodupl = credit_rating.drop_duplicates(keep='last') 

import numpy as np 
  
# numpy array 
credit_rating_nodupl['index'] = np.array([0, 1, 2, 3, 4, 5, 6]) 
credit_rating_nodupl = credit_rating_nodupl[['index', 'grade']]
# Out:
# /Users/Vlad/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
homeownership = df_sample[['home_ownership']].copy()
homeownership_nodupl = homeownership.drop_duplicates(keep='last')
import numpy as np 
  
# numpy array 
homeownership_nodupl['index'] = np.array([0, 1, 2]) 
homeownership_nodupl = homeownership_nodupl[['index', 'home_ownership']]
# Out:
# /Users/Vlad/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Out:
# array(['RENT', 'MORTGAGE', 'MORTGAGE', ..., 'MORTGAGE', 'RENT',
#        'MORTGAGE'], dtype=object)

# %%
loan_status.shape
# Out:
# (4000, 1)

# %%
loan.to_csv("/Users/Vlad/Desktop/Lending Club/CS3200/loan.csv")
borrower.to_csv("/Users/Vlad/Desktop/Lending Club/CS3200/borrower.csv")
loan_status_nodupl.to_csv("/Users/Vlad/Desktop/Lending Club/CS3200/loan_status.csv")
credit_rating_nodupl.to_csv("/Users/Vlad/Desktop/Lending Club/CS3200/credit_rating.csv")
homeownership_nodupl.to_csv("/Users/Vlad/Desktop/Lending Club/CS3200/homeownership.csv")

# %%
loan_status_nodupl.head()
# Out:
#         index         loan_status
# 493206      0   Late (16-30 days)
# 589019      1     In Grace Period
# 250418      2  Late (31-120 days)
# 144408      3         Charged Off
# 740145      4             Current

# %%
loan_status_nodupl.shape
# Out:
# (6, 2)

# %%
credit_rating_nodupl.shape
# Out:
# (7, 2)

# %%
homeownership_nodupl.shape
# Out:
# (3, 2)

# %%
homeownership_nodupl.head()
# Out:
#         index home_ownership
# 861155      0            OWN
# 740145      1           RENT
# 150763      2       MORTGAGE

# %%
borrower_memid = borrower['member_id'].copy()

# %%
borrower_memid.head()
# Out:
# 298882   NaN
# 410498   NaN
# 620244   NaN
# 614975   NaN
# 407779   NaN
# Name: member_id, dtype: float64

# %%
import random
random.sample(range(0, 5000), 4000)
# Out:
# [1668,
#  2529,
#  3163,
#  3945,
#  4284,
#  78,
#  912,
#  471,
#  1563,
#  2119,
#  194,
#  2742,
#  2297,
#  341,
#  4240,
#  584,
#  459,
#  1902,
#  4863,
#  1607,
#  2777,
#  140,
#  3222,
#  630,
#  4644,
#  1801,
#  3106,
#  3386,
#  4054,
#  2526,
#  3630,
#  3621,
#  4738,
#  864,
#  1319,
#  3915,
#  1698,
#  854,
#  118,
#  3731,
#  2266,
#  2209,
#  1383,
#  3716,
#  3108,
#  934,
#  3428,
#  4511,
#  3972,
#  4224,
#  4279,
#  4375,
#  3407,
#  1169,
#  916,
#  3058,
#  2264,
#  3928,
#  2977,
#  4510,
#  2756,
#  3083,
#  4614,
#  143,
#  3071,
#  2996,
#  3156,
#  609,
#  314,
#  3550,
#  3109,
#  4489,
#  1694,
#  2794,
#  785,
#  2008,
#  798,
#  1888,
#  2621,
#  3275,
#  4009,
#  4305,
#  4044,
#  2667,
#  3527,
#  3296,
#  1673,
#  3543,
#  39,
#  691,
#  3807,
#  867,
#  2199,
#  704,
#  3377,
#  866,
#  1859,
#  4212,
#  1210,
#  3934,
#  2534,
#  3220,
#  3243,
#  2593,
#  1808,
#  3161,
#  1044,
#  3198,
#  3512,
#  1893,
#  2359,
#  2687,
#  2421,
#  499,
# ...
